# %%
import re
import pickle
import random
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from timeit import default_timer as timer
import requests
# Out:
# C:\Users\Mx\AppData\Roaming\Python\Python37\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.4) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
url = "http://gutenberg.org/files/1342/1342-0.txt"
book = requests.get(url)
data = book.text
data = data[2440:]
print(len(data))
# Out:
# 797205

# %%
df = pd.read_csv("jokes.csv")
data = ' '.join(df['Joke'].tolist()).replace("\'", "")
print(len(data))
# Out:
# 128866

# %%
def clean_dataset(dataset):

    # remove whitespace
    tokenized = word_tokenize(dataset)
    dataset = " ".join([token.strip() for token in tokenized])

    # remove characters
    dataset = re.sub(r"[^\w\n]", " ", dataset)

    # replace multiple whitespaces with single whitespace
    dataset = re.sub(r"\s+", " ", dataset)
    dataset = dataset.strip()

    dataset = dataset.lower()
    dataset = dataset.replace("â", "a")
    
    return dataset

data = clean_dataset(data)

# %%
data1 = data
data1 = data1.split()
sequences = []
sequence_length = 10

for i in range(sequence_length, len(data1)):
    sequence = data1[i-sequence_length:i+1]
    sequences.append(sequence)
sequences = np.array(sequences)

XD = []
for x in sequences:
    XD.append(' '.join(x))
    
seqs = XD
seqs[0:1000]
# Out:
# ['what did the bartender say to the jumper cables you better',
#  'did the bartender say to the jumper cables you better not',
#  'the bartender say to the jumper cables you better not try',
#  'bartender say to the jumper cables you better not try to',
#  'say to the jumper cables you better not try to start',
#  'to the jumper cables you better not try to start anything',
#  'the jumper cables you better not try to start anything dont',
#  'jumper cables you better not try to start anything dont you',
#  'cables you better not try to start anything dont you hate',
#  'you better not try to start anything dont you hate jokes',
#  'better not try to start anything dont you hate jokes about',
#  'not try to start anything dont you hate jokes about german',
#  'try to start anything dont you hate jokes about german sausage',
#  'to start anything dont you hate jokes about german sausage theyre',
#  'start anything dont you hate jokes about german sausage theyre the',
#  'anything dont you hate jokes about german sausage theyre the wurst',
#  'dont you hate jokes about german sausage theyre the wurst two',
#  'you hate jokes about german sausage theyre the wurst two artists',
#  'hate jokes about german sausage theyre the wurst two artists had',
#  'jokes about german sausage theyre the wurst two artists had an',
#  'about german sausage theyre the wurst two artists had an art',
#  'german sausage theyre the wurst two artists had an art contest',
#  'sausage theyre the wurst two artists had an art contest it',
#  'theyre the wurst two artists had an art contest it ended',
#  'the wurst two artists had an art contest it ended in',
#  'wurst two artists had an art contest it ended in a',
#  'two artists had an art contest it ended in a draw',
#  'artists had an art contest it ended in a draw why',
#  'had an art contest it ended in a draw why did',
#  'an art contest it ended in a draw why did the',
#  'art contest it ended in a draw why did the chicken',
#  'contest it ended in a draw why did the chicken cross',
#  'it ended in a draw why did the chicken cross the',
#  'ended in a draw why did the chicken cross the playground',
#  'in a draw why did the chicken cross the playground to',
#  'a draw why did the chicken cross the playground to get',
#  'draw why did the chicken cross the playground to get to',
#  'why did the chicken cross the playground to get to the',
#  'did the chicken cross the playground to get to the other',
#  'the chicken cross the playground to get to the other slide',
#  'chicken cross the playground to get to the other slide what',
#  'cross the playground to get to the other slide what gun',
#  'the playground to get to the other slide what gun do',
#  'playground to get to the other slide what gun do you',
#  'to get to the other slide what gun do you use',
#  'get to the other slide what gun do you use to',
#  'to the other slide what gun do you use to hunt',
#  'the other slide what gun do you use to hunt a',
#  'other slide what gun do you use to hunt a moose',
#  'slide what gun do you use to hunt a moose a',
#  'what gun do you use to hunt a moose a moosecut',
#  'gun do you use to hunt a moose a moosecut if',
#  'do you use to hunt a moose a moosecut if life',
#  'you use to hunt a moose a moosecut if life gives',
#  'use to hunt a moose a moosecut if life gives you',
#  'to hunt a moose a moosecut if life gives you melons',
#  'hunt a moose a moosecut if life gives you melons you',
#  'a moose a moosecut if life gives you melons you might',
#  'moose a moosecut if life gives you melons you might have',
#  'a moosecut if life gives you melons you might have dyslexia',
#  'moosecut if life gives you melons you might have dyslexia broken',
#  'if life gives you melons you might have dyslexia broken pencils',
#  'life gives you melons you might have dyslexia broken pencils are',
#  'gives you melons you might have dyslexia broken pencils are pointless',
#  'you melons you might have dyslexia broken pencils are pointless what',
#  'melons you might have dyslexia broken pencils are pointless what did',
#  'you might have dyslexia broken pencils are pointless what did one',
#  'might have dyslexia broken pencils are pointless what did one snowman',
#  'have dyslexia broken pencils are pointless what did one snowman say',
#  'dyslexia broken pencils are pointless what did one snowman say to',
#  'broken pencils are pointless what did one snowman say to the',
#  'pencils are pointless what did one snowman say to the other',
#  'are pointless what did one snowman say to the other snowman',
#  'pointless what did one snowman say to the other snowman do',
#  'what did one snowman say to the other snowman do you',
#  'did one snowman say to the other snowman do you smell',
#  'one snowman say to the other snowman do you smell carrots',
#  'snowman say to the other snowman do you smell carrots how',
#  'say to the other snowman do you smell carrots how many',
#  'to the other snowman do you smell carrots how many hipsters',
#  'the other snowman do you smell carrots how many hipsters does',
#  'other snowman do you smell carrots how many hipsters does it',
#  'snowman do you smell carrots how many hipsters does it take',
#  'do you smell carrots how many hipsters does it take to',
#  'you smell carrots how many hipsters does it take to change',
#  'smell carrots how many hipsters does it take to change a',
#  'carrots how many hipsters does it take to change a lightbulb',
#  'how many hipsters does it take to change a lightbulb its',
#  'many hipsters does it take to change a lightbulb its a',
#  'hipsters does it take to change a lightbulb its a really',
#  'does it take to change a lightbulb its a really obscure',
#  'it take to change a lightbulb its a really obscure number',
#  'take to change a lightbulb its a really obscure number youve',
#  'to change a lightbulb its a really obscure number youve probably',
#  'change a lightbulb its a really obscure number youve probably never',
#  'a lightbulb its a really obscure number youve probably never heard',
#  'lightbulb its a really obscure number youve probably never heard of',
#  'its a really obscure number youve probably never heard of it',
#  'a really obscure number youve probably never heard of it where',
#  'really obscure number youve probably never heard of it where do',
#  'obscure number youve probably never heard of it where do sick',
#  'number youve probably never heard of it where do sick boats',
#  'youve probably never heard of it where do sick boats go',
#  'probably never heard of it where do sick boats go the',
#  'never heard of it where do sick boats go the dock',
#  'heard of it where do sick boats go the dock i',
#  'of it where do sick boats go the dock i like',
#  'it where do sick boats go the dock i like my',
#  'where do sick boats go the dock i like my slaves',
#  'do sick boats go the dock i like my slaves like',
#  'sick boats go the dock i like my slaves like i',
#  'boats go the dock i like my slaves like i like',
#  'go the dock i like my slaves like i like my',
#  'the dock i like my slaves like i like my coffee',
#  'dock i like my slaves like i like my coffee free',
#  'i like my slaves like i like my coffee free my',
#  'like my slaves like i like my coffee free my girlfriend',
#  'my slaves like i like my coffee free my girlfriend told',
#  'slaves like i like my coffee free my girlfriend told me',
#  'like i like my coffee free my girlfriend told me she',
#  'i like my coffee free my girlfriend told me she was',
#  'like my coffee free my girlfriend told me she was leaving',
#  'my coffee free my girlfriend told me she was leaving me',
#  'coffee free my girlfriend told me she was leaving me because',
#  'free my girlfriend told me she was leaving me because i',
#  'my girlfriend told me she was leaving me because i keep',
#  'girlfriend told me she was leaving me because i keep pretending',
#  'told me she was leaving me because i keep pretending to',
#  'me she was leaving me because i keep pretending to be',
#  'she was leaving me because i keep pretending to be a',
#  'was leaving me because i keep pretending to be a transformer',
#  'leaving me because i keep pretending to be a transformer i',
#  'me because i keep pretending to be a transformer i said',
#  'because i keep pretending to be a transformer i said no',
#  'i keep pretending to be a transformer i said no wait',
#  'keep pretending to be a transformer i said no wait i',
#  'pretending to be a transformer i said no wait i can',
#  'to be a transformer i said no wait i can change',
#  'be a transformer i said no wait i can change old',
#  'a transformer i said no wait i can change old chinese',
#  'transformer i said no wait i can change old chinese proverb',
#  'i said no wait i can change old chinese proverb man',
#  'said no wait i can change old chinese proverb man who',
#  'no wait i can change old chinese proverb man who not',
#  'wait i can change old chinese proverb man who not shower',
#  'i can change old chinese proverb man who not shower in',
#  'can change old chinese proverb man who not shower in 7',
#  'change old chinese proverb man who not shower in 7 days',
#  'old chinese proverb man who not shower in 7 days makes',
#  'chinese proverb man who not shower in 7 days makes one',
#  'proverb man who not shower in 7 days makes one reek',
#  'man who not shower in 7 days makes one reek what',
#  'who not shower in 7 days makes one reek what did',
#  'not shower in 7 days makes one reek what did the',
#  'shower in 7 days makes one reek what did the owner',
#  'in 7 days makes one reek what did the owner of',
#  '7 days makes one reek what did the owner of a',
#  'days makes one reek what did the owner of a brownie',
#  'makes one reek what did the owner of a brownie factory',
#  'one reek what did the owner of a brownie factory say',
#  'reek what did the owner of a brownie factory say when',
#  'what did the owner of a brownie factory say when his',
#  'did the owner of a brownie factory say when his factory',
#  'the owner of a brownie factory say when his factory caught',
#  'owner of a brownie factory say when his factory caught fire',
#  'of a brownie factory say when his factory caught fire im',
#  'a brownie factory say when his factory caught fire im getting',
#  'brownie factory say when his factory caught fire im getting the',
#  'factory say when his factory caught fire im getting the fudge',
#  'say when his factory caught fire im getting the fudge outta',
#  'when his factory caught fire im getting the fudge outta here',
#  'his factory caught fire im getting the fudge outta here what',
#  'factory caught fire im getting the fudge outta here what form',
#  'caught fire im getting the fudge outta here what form of',
#  'fire im getting the fudge outta here what form of radiation',
#  'im getting the fudge outta here what form of radiation bakes',
#  'getting the fudge outta here what form of radiation bakes you',
#  'the fudge outta here what form of radiation bakes you cookies',
#  'fudge outta here what form of radiation bakes you cookies a',
#  'outta here what form of radiation bakes you cookies a gramma',
#  'here what form of radiation bakes you cookies a gramma ray',
#  'what form of radiation bakes you cookies a gramma ray bee',
#  'form of radiation bakes you cookies a gramma ray bee jokes',
#  'of radiation bakes you cookies a gramma ray bee jokes courtesy',
#  'radiation bakes you cookies a gramma ray bee jokes courtesy of',
#  'bakes you cookies a gramma ray bee jokes courtesy of my',
#  'you cookies a gramma ray bee jokes courtesy of my niece',
#  'cookies a gramma ray bee jokes courtesy of my niece age',
#  'a gramma ray bee jokes courtesy of my niece age 8',
#  'gramma ray bee jokes courtesy of my niece age 8 what',
#  'ray bee jokes courtesy of my niece age 8 what did',
#  'bee jokes courtesy of my niece age 8 what did the',
#  'jokes courtesy of my niece age 8 what did the bee',
#  'courtesy of my niece age 8 what did the bee use',
#  'of my niece age 8 what did the bee use to',
#  'my niece age 8 what did the bee use to dry',
#  'niece age 8 what did the bee use to dry off',
#  'age 8 what did the bee use to dry off after',
#  '8 what did the bee use to dry off after swimming',
#  'what did the bee use to dry off after swimming a',
#  'did the bee use to dry off after swimming a bee',
#  'the bee use to dry off after swimming a bee ch',
#  'bee use to dry off after swimming a bee ch towel',
#  'use to dry off after swimming a bee ch towel what',
#  'to dry off after swimming a bee ch towel what did',
#  'dry off after swimming a bee ch towel what did the',
#  'off after swimming a bee ch towel what did the bee',
#  'after swimming a bee ch towel what did the bee use',
#  'swimming a bee ch towel what did the bee use to',
#  'a bee ch towel what did the bee use to get',
#  'bee ch towel what did the bee use to get out',
#  'ch towel what did the bee use to get out the',
#  'towel what did the bee use to get out the tangles',
#  'what did the bee use to get out the tangles a',
#  'did the bee use to get out the tangles a honeycomb',
#  'the bee use to get out the tangles a honeycomb whats',
#  'bee use to get out the tangles a honeycomb whats the',
#  'use to get out the tangles a honeycomb whats the loudest',
#  'to get out the tangles a honeycomb whats the loudest economic',
#  'get out the tangles a honeycomb whats the loudest economic system',
#  'out the tangles a honeycomb whats the loudest economic system capitalism',
#  'the tangles a honeycomb whats the loudest economic system capitalism i',
#  'tangles a honeycomb whats the loudest economic system capitalism i went',
#  'a honeycomb whats the loudest economic system capitalism i went for',
#  'honeycomb whats the loudest economic system capitalism i went for a',
#  'whats the loudest economic system capitalism i went for a job',
#  'the loudest economic system capitalism i went for a job interview',
#  'loudest economic system capitalism i went for a job interview today',
#  'economic system capitalism i went for a job interview today the',
#  'system capitalism i went for a job interview today the interviewer',
#  'capitalism i went for a job interview today the interviewer said',
#  'i went for a job interview today the interviewer said to',
#  'went for a job interview today the interviewer said to me',
#  'for a job interview today the interviewer said to me what',
#  'a job interview today the interviewer said to me what would',
#  'job interview today the interviewer said to me what would you',
#  'interview today the interviewer said to me what would you say',
#  'today the interviewer said to me what would you say your',
#  'the interviewer said to me what would you say your greatest',
#  'interviewer said to me what would you say your greatest weakness',
#  'said to me what would you say your greatest weakness is',
#  'to me what would you say your greatest weakness is i',
#  'me what would you say your greatest weakness is i said',
#  'what would you say your greatest weakness is i said i',
#  'would you say your greatest weakness is i said i think',
#  'you say your greatest weakness is i said i think id',
#  'say your greatest weakness is i said i think id have',
#  'your greatest weakness is i said i think id have to',
#  'greatest weakness is i said i think id have to say',
#  'weakness is i said i think id have to say my',
#  'is i said i think id have to say my listening',
#  'i said i think id have to say my listening skills',
#  'said i think id have to say my listening skills are',
#  'i think id have to say my listening skills are my',
#  'think id have to say my listening skills are my greatest',
#  'id have to say my listening skills are my greatest strength',
#  'have to say my listening skills are my greatest strength who',
#  'to say my listening skills are my greatest strength who was',
#  'say my listening skills are my greatest strength who was the',
#  'my listening skills are my greatest strength who was the knight',
#  'listening skills are my greatest strength who was the knight that',
#  'skills are my greatest strength who was the knight that invented',
#  'are my greatest strength who was the knight that invented the',
#  'my greatest strength who was the knight that invented the round',
#  'greatest strength who was the knight that invented the round table',
#  'strength who was the knight that invented the round table sir',
#  'who was the knight that invented the round table sir cumference',
#  'was the knight that invented the round table sir cumference via',
#  'the knight that invented the round table sir cumference via friend',
#  'knight that invented the round table sir cumference via friend who',
#  'that invented the round table sir cumference via friend who got',
#  'invented the round table sir cumference via friend who got this',
#  'the round table sir cumference via friend who got this from',
#  'round table sir cumference via friend who got this from a',
#  'table sir cumference via friend who got this from a street',
#  'sir cumference via friend who got this from a street performance',
#  'cumference via friend who got this from a street performance group',
#  'via friend who got this from a street performance group in',
#  'friend who got this from a street performance group in the',
#  'who got this from a street performance group in the england',
#  'got this from a street performance group in the england area',
#  'this from a street performance group in the england area of',
#  'from a street performance group in the england area of epcot',
#  'a street performance group in the england area of epcot what',
#  'street performance group in the england area of epcot what did',
#  'performance group in the england area of epcot what did the',
#  'group in the england area of epcot what did the german',
#  'in the england area of epcot what did the german air',
#  'the england area of epcot what did the german air force',
#  'england area of epcot what did the german air force eat',
#  'area of epcot what did the german air force eat for',
#  'of epcot what did the german air force eat for breakfast',
#  'epcot what did the german air force eat for breakfast during',
#  'what did the german air force eat for breakfast during ww2',
#  'did the german air force eat for breakfast during ww2 luftwaffles',
#  'the german air force eat for breakfast during ww2 luftwaffles i',
#  'german air force eat for breakfast during ww2 luftwaffles i the',
#  'air force eat for breakfast during ww2 luftwaffles i the shell',
#  'force eat for breakfast during ww2 luftwaffles i the shell off',
#  'eat for breakfast during ww2 luftwaffles i the shell off a',
#  'for breakfast during ww2 luftwaffles i the shell off a snail',
#  'breakfast during ww2 luftwaffles i the shell off a snail yesterday',
#  'during ww2 luftwaffles i the shell off a snail yesterday youd',
#  'ww2 luftwaffles i the shell off a snail yesterday youd think',
#  'luftwaffles i the shell off a snail yesterday youd think it',
#  'i the shell off a snail yesterday youd think it would',
#  'the shell off a snail yesterday youd think it would move',
#  'shell off a snail yesterday youd think it would move faster',
#  'off a snail yesterday youd think it would move faster but',
#  'a snail yesterday youd think it would move faster but it',
#  'snail yesterday youd think it would move faster but it was',
#  'yesterday youd think it would move faster but it was really',
#  'youd think it would move faster but it was really kinda',
#  'think it would move faster but it was really kinda sluggish',
#  'it would move faster but it was really kinda sluggish what',
#  'would move faster but it was really kinda sluggish what did',
#  'move faster but it was really kinda sluggish what did the',
#  'faster but it was really kinda sluggish what did the number',
#  'but it was really kinda sluggish what did the number zero',
#  'it was really kinda sluggish what did the number zero say',
#  'was really kinda sluggish what did the number zero say to',
#  'really kinda sluggish what did the number zero say to the',
#  'kinda sluggish what did the number zero say to the number',
#  'sluggish what did the number zero say to the number eight',
#  'what did the number zero say to the number eight nice',
#  'did the number zero say to the number eight nice belt',
#  'the number zero say to the number eight nice belt whats',
#  'number zero say to the number eight nice belt whats worse',
#  'zero say to the number eight nice belt whats worse than',
#  'say to the number eight nice belt whats worse than a',
#  'to the number eight nice belt whats worse than a centipede',
#  'the number eight nice belt whats worse than a centipede with',
#  'number eight nice belt whats worse than a centipede with sore',
#  'eight nice belt whats worse than a centipede with sore feet',
#  'nice belt whats worse than a centipede with sore feet a',
#  'belt whats worse than a centipede with sore feet a giraffe',
#  'whats worse than a centipede with sore feet a giraffe with',
#  'worse than a centipede with sore feet a giraffe with a',
#  'than a centipede with sore feet a giraffe with a sore',
#  'a centipede with sore feet a giraffe with a sore throat',
#  'centipede with sore feet a giraffe with a sore throat whats',
#  'with sore feet a giraffe with a sore throat whats red',
#  'sore feet a giraffe with a sore throat whats red and',
#  'feet a giraffe with a sore throat whats red and bad',
#  'a giraffe with a sore throat whats red and bad for',
#  'giraffe with a sore throat whats red and bad for your',
#  'with a sore throat whats red and bad for your teeth',
#  'a sore throat whats red and bad for your teeth a',
#  'sore throat whats red and bad for your teeth a brick',
#  'throat whats red and bad for your teeth a brick why',
#  'whats red and bad for your teeth a brick why did',
#  'red and bad for your teeth a brick why did the',
#  'and bad for your teeth a brick why did the chicken',
#  'bad for your teeth a brick why did the chicken cross',
#  'for your teeth a brick why did the chicken cross the',
#  'your teeth a brick why did the chicken cross the playground',
#  'teeth a brick why did the chicken cross the playground to',
#  'a brick why did the chicken cross the playground to get',
#  'brick why did the chicken cross the playground to get to',
#  'why did the chicken cross the playground to get to the',
#  'did the chicken cross the playground to get to the other',
#  'the chicken cross the playground to get to the other slide',
#  'chicken cross the playground to get to the other slide did',
#  'cross the playground to get to the other slide did you',
#  'the playground to get to the other slide did you hear',
#  'playground to get to the other slide did you hear about',
#  'to get to the other slide did you hear about the',
#  'get to the other slide did you hear about the french',
#  'to the other slide did you hear about the french chef',
#  'the other slide did you hear about the french chef who',
#  'other slide did you hear about the french chef who committed',
#  'slide did you hear about the french chef who committed suicide',
#  'did you hear about the french chef who committed suicide he',
#  'you hear about the french chef who committed suicide he lost',
#  'hear about the french chef who committed suicide he lost the',
#  'about the french chef who committed suicide he lost the huile',
#  'the french chef who committed suicide he lost the huile dolive',
#  'french chef who committed suicide he lost the huile dolive wan',
#  'chef who committed suicide he lost the huile dolive wan na',
#  'who committed suicide he lost the huile dolive wan na hear',
#  'committed suicide he lost the huile dolive wan na hear a',
#  'suicide he lost the huile dolive wan na hear a joke',
#  'he lost the huile dolive wan na hear a joke about',
#  'lost the huile dolive wan na hear a joke about unemployed',
#  'the huile dolive wan na hear a joke about unemployed people',
#  'huile dolive wan na hear a joke about unemployed people nevermind',
#  'dolive wan na hear a joke about unemployed people nevermind they',
#  'wan na hear a joke about unemployed people nevermind they dont',
#  'na hear a joke about unemployed people nevermind they dont work',
#  'hear a joke about unemployed people nevermind they dont work knock',
#  'a joke about unemployed people nevermind they dont work knock knock',
#  'joke about unemployed people nevermind they dont work knock knock whos',
#  'about unemployed people nevermind they dont work knock knock whos there',
#  'unemployed people nevermind they dont work knock knock whos there boo',
#  'people nevermind they dont work knock knock whos there boo boo',
#  'nevermind they dont work knock knock whos there boo boo who',
#  'they dont work knock knock whos there boo boo who dont',
#  'dont work knock knock whos there boo boo who dont cry',
#  'work knock knock whos there boo boo who dont cry its',
#  'knock knock whos there boo boo who dont cry its only',
#  'knock whos there boo boo who dont cry its only a',
#  'whos there boo boo who dont cry its only a joke',
#  'there boo boo who dont cry its only a joke how',
#  'boo boo who dont cry its only a joke how much',
#  'boo who dont cry its only a joke how much did',
#  'who dont cry its only a joke how much did the',
#  'dont cry its only a joke how much did the skeleton',
#  'cry its only a joke how much did the skeleton charge',
#  'its only a joke how much did the skeleton charge for',
#  'only a joke how much did the skeleton charge for his',
#  'a joke how much did the skeleton charge for his excellent',
#  'joke how much did the skeleton charge for his excellent legal',
#  'how much did the skeleton charge for his excellent legal services',
#  'much did the skeleton charge for his excellent legal services an',
#  'did the skeleton charge for his excellent legal services an arm',
#  'the skeleton charge for his excellent legal services an arm and',
#  'skeleton charge for his excellent legal services an arm and a',
#  'charge for his excellent legal services an arm and a leg',
#  'for his excellent legal services an arm and a leg why',
#  'his excellent legal services an arm and a leg why do',
#  'excellent legal services an arm and a leg why do gorillas',
#  'legal services an arm and a leg why do gorillas have',
#  'services an arm and a leg why do gorillas have such',
#  'an arm and a leg why do gorillas have such big',
#  'arm and a leg why do gorillas have such big nostrils',
#  'and a leg why do gorillas have such big nostrils cos',
#  'a leg why do gorillas have such big nostrils cos they',
#  'leg why do gorillas have such big nostrils cos they got',
#  'why do gorillas have such big nostrils cos they got big',
#  'do gorillas have such big nostrils cos they got big fingers',
#  'gorillas have such big nostrils cos they got big fingers what',
#  'have such big nostrils cos they got big fingers what is',
#  'such big nostrils cos they got big fingers what is the',
#  'big nostrils cos they got big fingers what is the difference',
#  'nostrils cos they got big fingers what is the difference between',
#  'cos they got big fingers what is the difference between a',
#  'they got big fingers what is the difference between a siberian',
#  'got big fingers what is the difference between a siberian husky',
#  'big fingers what is the difference between a siberian husky and',
#  'fingers what is the difference between a siberian husky and an',
#  'what is the difference between a siberian husky and an alaskan',
#  'is the difference between a siberian husky and an alaskan husky',
#  'the difference between a siberian husky and an alaskan husky about',
#  'difference between a siberian husky and an alaskan husky about 1500',
#  'between a siberian husky and an alaskan husky about 1500 miles',
#  'a siberian husky and an alaskan husky about 1500 miles what',
#  'siberian husky and an alaskan husky about 1500 miles what do',
#  'husky and an alaskan husky about 1500 miles what do vegan',
#  'and an alaskan husky about 1500 miles what do vegan zombies',
#  'an alaskan husky about 1500 miles what do vegan zombies eat',
#  'alaskan husky about 1500 miles what do vegan zombies eat graaaiiinsss',
#  'husky about 1500 miles what do vegan zombies eat graaaiiinsss whats',
#  'about 1500 miles what do vegan zombies eat graaaiiinsss whats the',
#  '1500 miles what do vegan zombies eat graaaiiinsss whats the difference',
#  'miles what do vegan zombies eat graaaiiinsss whats the difference between',
#  'what do vegan zombies eat graaaiiinsss whats the difference between a',
#  'do vegan zombies eat graaaiiinsss whats the difference between a thai',
#  'vegan zombies eat graaaiiinsss whats the difference between a thai man',
#  'zombies eat graaaiiinsss whats the difference between a thai man and',
#  'eat graaaiiinsss whats the difference between a thai man and a',
#  'graaaiiinsss whats the difference between a thai man and a thai',
#  'whats the difference between a thai man and a thai woman',
#  'the difference between a thai man and a thai woman pls',
#  'difference between a thai man and a thai woman pls help',
#  'between a thai man and a thai woman pls help what',
#  'a thai man and a thai woman pls help what do',
#  'thai man and a thai woman pls help what do you',
#  'man and a thai woman pls help what do you call',
#  'and a thai woman pls help what do you call a',
#  'a thai woman pls help what do you call a car',
#  'thai woman pls help what do you call a car that',
#  'woman pls help what do you call a car that eats',
#  'pls help what do you call a car that eats other',
#  'help what do you call a car that eats other cars',
#  'what do you call a car that eats other cars a',
#  'do you call a car that eats other cars a carnivore',
#  'you call a car that eats other cars a carnivore why',
#  'call a car that eats other cars a carnivore why did',
#  'a car that eats other cars a carnivore why did the',
#  'car that eats other cars a carnivore why did the golfer',
#  'that eats other cars a carnivore why did the golfer wear',
#  'eats other cars a carnivore why did the golfer wear two',
#  'other cars a carnivore why did the golfer wear two pairs',
#  'cars a carnivore why did the golfer wear two pairs of',
#  'a carnivore why did the golfer wear two pairs of pants',
#  'carnivore why did the golfer wear two pairs of pants in',
#  'why did the golfer wear two pairs of pants in case',
#  'did the golfer wear two pairs of pants in case he',
#  'the golfer wear two pairs of pants in case he gets',
#  'golfer wear two pairs of pants in case he gets a',
#  'wear two pairs of pants in case he gets a hole',
#  'two pairs of pants in case he gets a hole in',
#  'pairs of pants in case he gets a hole in one',
#  'of pants in case he gets a hole in one an',
#  'pants in case he gets a hole in one an olympic',
#  'in case he gets a hole in one an olympic gymnast',
#  'case he gets a hole in one an olympic gymnast walked',
#  'he gets a hole in one an olympic gymnast walked into',
#  'gets a hole in one an olympic gymnast walked into a',
#  'a hole in one an olympic gymnast walked into a bar',
#  'hole in one an olympic gymnast walked into a bar she',
#  'in one an olympic gymnast walked into a bar she didnt',
#  'one an olympic gymnast walked into a bar she didnt get',
#  'an olympic gymnast walked into a bar she didnt get a',
#  'olympic gymnast walked into a bar she didnt get a medal',
#  'gymnast walked into a bar she didnt get a medal what',
#  'walked into a bar she didnt get a medal what does',
#  'into a bar she didnt get a medal what does a',
#  'a bar she didnt get a medal what does a mexican',
#  'bar she didnt get a medal what does a mexican magician',
#  'she didnt get a medal what does a mexican magician make',
#  'didnt get a medal what does a mexican magician make for',
#  'get a medal what does a mexican magician make for breakfast',
#  'a medal what does a mexican magician make for breakfast toast',
#  'medal what does a mexican magician make for breakfast toast tah',
#  'what does a mexican magician make for breakfast toast tah dahs',
#  'does a mexican magician make for breakfast toast tah dahs why',
#  'a mexican magician make for breakfast toast tah dahs why dont',
#  'mexican magician make for breakfast toast tah dahs why dont bond',
#  'magician make for breakfast toast tah dahs why dont bond villains',
#  'make for breakfast toast tah dahs why dont bond villains feel',
#  'for breakfast toast tah dahs why dont bond villains feel cold',
#  'breakfast toast tah dahs why dont bond villains feel cold in',
#  'toast tah dahs why dont bond villains feel cold in the',
#  'tah dahs why dont bond villains feel cold in the winter',
#  'dahs why dont bond villains feel cold in the winter because',
#  'why dont bond villains feel cold in the winter because they',
#  'dont bond villains feel cold in the winter because they dress',
#  'bond villains feel cold in the winter because they dress in',
#  'villains feel cold in the winter because they dress in lairs',
#  'feel cold in the winter because they dress in lairs what',
#  'cold in the winter because they dress in lairs what did',
#  'in the winter because they dress in lairs what did the',
#  'the winter because they dress in lairs what did the figurine',
#  'winter because they dress in lairs what did the figurine say',
#  'because they dress in lairs what did the figurine say when',
#  'they dress in lairs what did the figurine say when the',
#  'dress in lairs what did the figurine say when the boot',
#  'in lairs what did the figurine say when the boot flew',
#  'lairs what did the figurine say when the boot flew past',
#  'what did the figurine say when the boot flew past her',
#  'did the figurine say when the boot flew past her protective',
#  'the figurine say when the boot flew past her protective dome',
#  'figurine say when the boot flew past her protective dome that',
#  'say when the boot flew past her protective dome that was',
#  'when the boot flew past her protective dome that was a',
#  'the boot flew past her protective dome that was a cloche',
#  'boot flew past her protective dome that was a cloche call',
#  'flew past her protective dome that was a cloche call what',
#  'past her protective dome that was a cloche call what was',
#  'her protective dome that was a cloche call what was carl',
#  'protective dome that was a cloche call what was carl sagans',
#  'dome that was a cloche call what was carl sagans favorite',
#  'that was a cloche call what was carl sagans favorite drink',
#  'was a cloche call what was carl sagans favorite drink cosmos',
#  'a cloche call what was carl sagans favorite drink cosmos what',
#  'cloche call what was carl sagans favorite drink cosmos what is',
#  'call what was carl sagans favorite drink cosmos what is the',
#  'what was carl sagans favorite drink cosmos what is the medical',
#  'was carl sagans favorite drink cosmos what is the medical term',
#  'carl sagans favorite drink cosmos what is the medical term for',
#  'sagans favorite drink cosmos what is the medical term for owning',
#  'favorite drink cosmos what is the medical term for owning too',
#  'drink cosmos what is the medical term for owning too many',
#  'cosmos what is the medical term for owning too many dogs',
#  'what is the medical term for owning too many dogs a',
#  'is the medical term for owning too many dogs a roverdose',
#  'the medical term for owning too many dogs a roverdose http',
#  'medical term for owning too many dogs a roverdose http i',
#  'term for owning too many dogs a roverdose http i imgur',
#  'for owning too many dogs a roverdose http i imgur com',
#  'owning too many dogs a roverdose http i imgur com btyf5ys',
#  'too many dogs a roverdose http i imgur com btyf5ys jpg',
#  'many dogs a roverdose http i imgur com btyf5ys jpg knock',
#  'dogs a roverdose http i imgur com btyf5ys jpg knock knock',
#  'a roverdose http i imgur com btyf5ys jpg knock knock whos',
#  'roverdose http i imgur com btyf5ys jpg knock knock whos there',
#  'http i imgur com btyf5ys jpg knock knock whos there i',
#  'i imgur com btyf5ys jpg knock knock whos there i did',
#  'imgur com btyf5ys jpg knock knock whos there i did up',
#  'com btyf5ys jpg knock knock whos there i did up i',
#  'btyf5ys jpg knock knock whos there i did up i did',
#  'jpg knock knock whos there i did up i did up',
#  'knock knock whos there i did up i did up who',
#  'knock whos there i did up i did up who i',
#  'whos there i did up i did up who i like',
#  'there i did up i did up who i like my',
#  'i did up i did up who i like my jokes',
#  'did up i did up who i like my jokes they',
#  'up i did up who i like my jokes they way',
#  'i did up who i like my jokes they way i',
#  'did up who i like my jokes they way i like',
#  'up who i like my jokes they way i like my',
#  'who i like my jokes they way i like my robots',
#  'i like my jokes they way i like my robots killer',
#  'like my jokes they way i like my robots killer what',
#  'my jokes they way i like my robots killer what type',
#  'jokes they way i like my robots killer what type of',
#  'they way i like my robots killer what type of school',
#  'way i like my robots killer what type of school did',
#  'i like my robots killer what type of school did sherlock',
#  'like my robots killer what type of school did sherlock holmes',
#  'my robots killer what type of school did sherlock holmes go',
#  'robots killer what type of school did sherlock holmes go to',
#  'killer what type of school did sherlock holmes go to elementary',
#  'what type of school did sherlock holmes go to elementary my',
#  'type of school did sherlock holmes go to elementary my friend',
#  'of school did sherlock holmes go to elementary my friend told',
#  'school did sherlock holmes go to elementary my friend told an',
#  'did sherlock holmes go to elementary my friend told an out',
#  'sherlock holmes go to elementary my friend told an out of',
#  'holmes go to elementary my friend told an out of place',
#  'go to elementary my friend told an out of place joke',
#  'to elementary my friend told an out of place joke about',
#  'elementary my friend told an out of place joke about police',
#  'my friend told an out of place joke about police searches',
#  'friend told an out of place joke about police searches but',
#  'told an out of place joke about police searches but i',
#  'an out of place joke about police searches but i dont',
#  'out of place joke about police searches but i dont think',
#  'of place joke about police searches but i dont think it',
#  'place joke about police searches but i dont think it was',
#  'joke about police searches but i dont think it was warranted',
#  'about police searches but i dont think it was warranted the',
#  'police searches but i dont think it was warranted the dalai',
#  'searches but i dont think it was warranted the dalai lama',
#  'but i dont think it was warranted the dalai lama walks',
#  'i dont think it was warranted the dalai lama walks into',
#  'dont think it was warranted the dalai lama walks into a',
#  'think it was warranted the dalai lama walks into a pizza',
#  'it was warranted the dalai lama walks into a pizza store',
#  'was warranted the dalai lama walks into a pizza store and',
#  'warranted the dalai lama walks into a pizza store and says',
#  'the dalai lama walks into a pizza store and says can',
#  'dalai lama walks into a pizza store and says can you',
#  'lama walks into a pizza store and says can you make',
#  'walks into a pizza store and says can you make me',
#  'into a pizza store and says can you make me one',
#  'a pizza store and says can you make me one with',
#  'pizza store and says can you make me one with everything',
#  'store and says can you make me one with everything why',
#  'and says can you make me one with everything why did',
#  'says can you make me one with everything why did the',
#  'can you make me one with everything why did the vampire',
#  'you make me one with everything why did the vampire use',
#  'make me one with everything why did the vampire use mouthwash',
#  'me one with everything why did the vampire use mouthwash because',
#  'one with everything why did the vampire use mouthwash because he',
#  'with everything why did the vampire use mouthwash because he had',
#  'everything why did the vampire use mouthwash because he had bat',
#  'why did the vampire use mouthwash because he had bat breath',
#  'did the vampire use mouthwash because he had bat breath what',
#  'the vampire use mouthwash because he had bat breath what did',
#  'vampire use mouthwash because he had bat breath what did the',
#  'use mouthwash because he had bat breath what did the corn',
#  'mouthwash because he had bat breath what did the corn say',
#  'because he had bat breath what did the corn say when',
#  'he had bat breath what did the corn say when it',
#  'had bat breath what did the corn say when it was',
#  'bat breath what did the corn say when it was complemented',
#  'breath what did the corn say when it was complemented aww',
#  'what did the corn say when it was complemented aww shucks',
#  'did the corn say when it was complemented aww shucks what',
#  'the corn say when it was complemented aww shucks what did',
#  'corn say when it was complemented aww shucks what did the',
#  'say when it was complemented aww shucks what did the green',
#  'when it was complemented aww shucks what did the green grape',
#  'it was complemented aww shucks what did the green grape say',
#  'was complemented aww shucks what did the green grape say to',
#  'complemented aww shucks what did the green grape say to the',
#  'aww shucks what did the green grape say to the purple',
#  'shucks what did the green grape say to the purple grape',
#  'what did the green grape say to the purple grape breathe',
#  'did the green grape say to the purple grape breathe stupid',
#  'the green grape say to the purple grape breathe stupid why',
#  'green grape say to the purple grape breathe stupid why did',
#  'grape say to the purple grape breathe stupid why did the',
#  'say to the purple grape breathe stupid why did the fall',
#  'to the purple grape breathe stupid why did the fall break',
#  'the purple grape breathe stupid why did the fall break off',
#  'purple grape breathe stupid why did the fall break off from',
#  'grape breathe stupid why did the fall break off from all',
#  'breathe stupid why did the fall break off from all the',
#  'stupid why did the fall break off from all the other',
#  'why did the fall break off from all the other seasons',
#  'did the fall break off from all the other seasons because',
#  'the fall break off from all the other seasons because it',
#  'fall break off from all the other seasons because it wanted',
#  'break off from all the other seasons because it wanted autumnomy',
#  'off from all the other seasons because it wanted autumnomy if',
#  'from all the other seasons because it wanted autumnomy if i',
#  'all the other seasons because it wanted autumnomy if i ever',
#  'the other seasons because it wanted autumnomy if i ever fire',
#  'other seasons because it wanted autumnomy if i ever fire someone',
#  'seasons because it wanted autumnomy if i ever fire someone who',
#  'because it wanted autumnomy if i ever fire someone who is',
#  'it wanted autumnomy if i ever fire someone who is a',
#  'wanted autumnomy if i ever fire someone who is a taylor',
#  'autumnomy if i ever fire someone who is a taylor swift',
#  'if i ever fire someone who is a taylor swift fan',
#  'i ever fire someone who is a taylor swift fan ill',
#  'ever fire someone who is a taylor swift fan ill say',
#  'fire someone who is a taylor swift fan ill say i',
#  'someone who is a taylor swift fan ill say i knew',
#  'who is a taylor swift fan ill say i knew you',
#  'is a taylor swift fan ill say i knew you were',
#  'a taylor swift fan ill say i knew you were trouble',
#  'taylor swift fan ill say i knew you were trouble when',
#  'swift fan ill say i knew you were trouble when you',
#  'fan ill say i knew you were trouble when you clocked',
#  'ill say i knew you were trouble when you clocked in',
#  'say i knew you were trouble when you clocked in what',
#  'i knew you were trouble when you clocked in what do',
#  'knew you were trouble when you clocked in what do you',
#  'you were trouble when you clocked in what do you do',
#  'were trouble when you clocked in what do you do if',
#  'trouble when you clocked in what do you do if a',
#  'when you clocked in what do you do if a cow',
#  'you clocked in what do you do if a cow is',
#  'clocked in what do you do if a cow is in',
#  'in what do you do if a cow is in the',
#  'what do you do if a cow is in the middle',
#  'do you do if a cow is in the middle of',
#  'you do if a cow is in the middle of the',
#  'do if a cow is in the middle of the road',
#  'if a cow is in the middle of the road youre',
#  'a cow is in the middle of the road youre driving',
#  'cow is in the middle of the road youre driving on',
#  'is in the middle of the road youre driving on steer',
#  'in the middle of the road youre driving on steer clear',
#  'the middle of the road youre driving on steer clear what',
#  'middle of the road youre driving on steer clear what do',
#  'of the road youre driving on steer clear what do you',
#  'the road youre driving on steer clear what do you call',
#  'road youre driving on steer clear what do you call a',
#  'youre driving on steer clear what do you call a blind',
#  'driving on steer clear what do you call a blind legless',
#  'on steer clear what do you call a blind legless buck',
#  'steer clear what do you call a blind legless buck no',
#  'clear what do you call a blind legless buck no eye',
#  'what do you call a blind legless buck no eye deer',
#  'do you call a blind legless buck no eye deer edit',
#  'you call a blind legless buck no eye deer edit i',
#  'call a blind legless buck no eye deer edit i totally',
#  'a blind legless buck no eye deer edit i totally messed',
#  'blind legless buck no eye deer edit i totally messed this',
#  'legless buck no eye deer edit i totally messed this joke',
#  'buck no eye deer edit i totally messed this joke up',
#  'no eye deer edit i totally messed this joke up please',
#  'eye deer edit i totally messed this joke up please give',
#  'deer edit i totally messed this joke up please give me',
#  'edit i totally messed this joke up please give me another',
#  'i totally messed this joke up please give me another chance',
#  'totally messed this joke up please give me another chance with',
#  'messed this joke up please give me another chance with another',
#  'this joke up please give me another chance with another joke',
#  'joke up please give me another chance with another joke what',
#  'up please give me another chance with another joke what do',
#  'please give me another chance with another joke what do you',
#  'give me another chance with another joke what do you get',
#  'me another chance with another joke what do you get for',
#  'another chance with another joke what do you get for the',
#  'chance with another joke what do you get for the women',
#  'with another joke what do you get for the women who',
#  'another joke what do you get for the women who has',
#  'joke what do you get for the women who has everything',
#  'what do you get for the women who has everything a',
#  'do you get for the women who has everything a divorce',
#  'you get for the women who has everything a divorce then',
#  'get for the women who has everything a divorce then shell',
#  'for the women who has everything a divorce then shell only',
#  'the women who has everything a divorce then shell only have',
#  'women who has everything a divorce then shell only have half',
#  'who has everything a divorce then shell only have half of',
#  'has everything a divorce then shell only have half of everything',
#  'everything a divorce then shell only have half of everything there',
#  'a divorce then shell only have half of everything there was',
#  'divorce then shell only have half of everything there was a',
#  'then shell only have half of everything there was a depressed',
#  'shell only have half of everything there was a depressed sausage',
#  'only have half of everything there was a depressed sausage he',
#  'have half of everything there was a depressed sausage he thought',
#  'half of everything there was a depressed sausage he thought his',
#  'of everything there was a depressed sausage he thought his life',
#  'everything there was a depressed sausage he thought his life was',
#  'there was a depressed sausage he thought his life was the',
#  'was a depressed sausage he thought his life was the wurst',
#  'a depressed sausage he thought his life was the wurst whats',
#  'depressed sausage he thought his life was the wurst whats a',
#  'sausage he thought his life was the wurst whats a dogs',
#  'he thought his life was the wurst whats a dogs favorite',
#  'thought his life was the wurst whats a dogs favorite mode',
#  'his life was the wurst whats a dogs favorite mode of',
#  'life was the wurst whats a dogs favorite mode of transportation',
#  'was the wurst whats a dogs favorite mode of transportation a',
#  'the wurst whats a dogs favorite mode of transportation a waggin',
#  'wurst whats a dogs favorite mode of transportation a waggin why',
#  'whats a dogs favorite mode of transportation a waggin why did',
#  'a dogs favorite mode of transportation a waggin why did the',
#  'dogs favorite mode of transportation a waggin why did the sand',
#  'favorite mode of transportation a waggin why did the sand dune',
#  'mode of transportation a waggin why did the sand dune blush',
#  'of transportation a waggin why did the sand dune blush because',
#  'transportation a waggin why did the sand dune blush because the',
#  'a waggin why did the sand dune blush because the sea',
#  'waggin why did the sand dune blush because the sea weed',
#  'why did the sand dune blush because the sea weed what',
#  'did the sand dune blush because the sea weed what happened',
#  'the sand dune blush because the sea weed what happened to',
#  'sand dune blush because the sea weed what happened to the',
#  'dune blush because the sea weed what happened to the tyrannical',
#  'blush because the sea weed what happened to the tyrannical peach',
#  'because the sea weed what happened to the tyrannical peach he',
#  'the sea weed what happened to the tyrannical peach he got',
#  'sea weed what happened to the tyrannical peach he got impeached',
#  'weed what happened to the tyrannical peach he got impeached why',
#  'what happened to the tyrannical peach he got impeached why do',
#  'happened to the tyrannical peach he got impeached why do elephants',
#  'to the tyrannical peach he got impeached why do elephants paint',
#  'the tyrannical peach he got impeached why do elephants paint their',
#  'tyrannical peach he got impeached why do elephants paint their toenails',
#  'peach he got impeached why do elephants paint their toenails red',
#  'he got impeached why do elephants paint their toenails red so',
#  'got impeached why do elephants paint their toenails red so they',
#  'impeached why do elephants paint their toenails red so they can',
#  'why do elephants paint their toenails red so they can hide',
#  'do elephants paint their toenails red so they can hide in',
#  'elephants paint their toenails red so they can hide in cherry',
#  'paint their toenails red so they can hide in cherry trees',
#  'their toenails red so they can hide in cherry trees you',
#  'toenails red so they can hide in cherry trees you ever',
#  'red so they can hide in cherry trees you ever seen',
#  'so they can hide in cherry trees you ever seen an',
#  'they can hide in cherry trees you ever seen an elephant',
#  'can hide in cherry trees you ever seen an elephant in',
#  'hide in cherry trees you ever seen an elephant in a',
#  'in cherry trees you ever seen an elephant in a cherry',
#  'cherry trees you ever seen an elephant in a cherry tree',
#  'trees you ever seen an elephant in a cherry tree then',
#  'you ever seen an elephant in a cherry tree then its',
#  'ever seen an elephant in a cherry tree then its working',
#  'seen an elephant in a cherry tree then its working what',
#  'an elephant in a cherry tree then its working what did',
#  'elephant in a cherry tree then its working what did the',
#  'in a cherry tree then its working what did the mexican',
#  'a cherry tree then its working what did the mexican firecheif',
#  'cherry tree then its working what did the mexican firecheif name',
#  'tree then its working what did the mexican firecheif name his',
#  'then its working what did the mexican firecheif name his kids',
#  'its working what did the mexican firecheif name his kids hose',
#  'working what did the mexican firecheif name his kids hose a',
#  'what did the mexican firecheif name his kids hose a and',
#  'did the mexican firecheif name his kids hose a and hose',
#  'the mexican firecheif name his kids hose a and hose b',
#  'mexican firecheif name his kids hose a and hose b what',
#  'firecheif name his kids hose a and hose b what did',
#  'name his kids hose a and hose b what did the',
#  'his kids hose a and hose b what did the german',
#  'kids hose a and hose b what did the german physicist',
#  'hose a and hose b what did the german physicist use',
#  'a and hose b what did the german physicist use to',
#  'and hose b what did the german physicist use to drink',
#  'hose b what did the german physicist use to drink his',
#  'b what did the german physicist use to drink his beer',
#  'what did the german physicist use to drink his beer ein',
#  'did the german physicist use to drink his beer ein stein',
#  'the german physicist use to drink his beer ein stein from',
#  'german physicist use to drink his beer ein stein from big',
#  'physicist use to drink his beer ein stein from big nate',
#  'use to drink his beer ein stein from big nate as',
#  'to drink his beer ein stein from big nate as told',
#  'drink his beer ein stein from big nate as told by',
#  'his beer ein stein from big nate as told by my',
#  'beer ein stein from big nate as told by my kid',
#  'ein stein from big nate as told by my kid what',
#  'stein from big nate as told by my kid what did',
#  'from big nate as told by my kid what did earth',
#  'big nate as told by my kid what did earth say',
#  'nate as told by my kid what did earth say to',
#  'as told by my kid what did earth say to the',
#  'told by my kid what did earth say to the other',
#  'by my kid what did earth say to the other planets',
#  'my kid what did earth say to the other planets you',
#  'kid what did earth say to the other planets you guys',
#  'what did earth say to the other planets you guys have',
#  'did earth say to the other planets you guys have no',
#  'earth say to the other planets you guys have no life',
#  'say to the other planets you guys have no life one',
#  'to the other planets you guys have no life one time',
#  'the other planets you guys have no life one time we',
#  'other planets you guys have no life one time we ran',
#  'planets you guys have no life one time we ran out',
#  'you guys have no life one time we ran out of',
#  'guys have no life one time we ran out of soap',
#  'have no life one time we ran out of soap so',
#  'no life one time we ran out of soap so we',
#  'life one time we ran out of soap so we had',
#  'one time we ran out of soap so we had to',
#  'time we ran out of soap so we had to use',
#  'we ran out of soap so we had to use hand',
#  'ran out of soap so we had to use hand sanitizer',
#  'out of soap so we had to use hand sanitizer wan',
#  'of soap so we had to use hand sanitizer wan na',
#  'soap so we had to use hand sanitizer wan na hear',
#  'so we had to use hand sanitizer wan na hear a',
#  'we had to use hand sanitizer wan na hear a dirty',
#  'had to use hand sanitizer wan na hear a dirty joke',
#  'to use hand sanitizer wan na hear a dirty joke two',
#  'use hand sanitizer wan na hear a dirty joke two white',
#  'hand sanitizer wan na hear a dirty joke two white stallions',
#  'sanitizer wan na hear a dirty joke two white stallions fell',
#  'wan na hear a dirty joke two white stallions fell in',
#  'na hear a dirty joke two white stallions fell in the',
#  'hear a dirty joke two white stallions fell in the mud',
#  'a dirty joke two white stallions fell in the mud what',
#  'dirty joke two white stallions fell in the mud what did',
#  'joke two white stallions fell in the mud what did one',
#  'two white stallions fell in the mud what did one frog',
#  'white stallions fell in the mud what did one frog say',
#  'stallions fell in the mud what did one frog say to',
#  'fell in the mud what did one frog say to the',
#  'in the mud what did one frog say to the other',
#  'the mud what did one frog say to the other frog',
#  'mud what did one frog say to the other frog times',
#  'what did one frog say to the other frog times fun',
#  'did one frog say to the other frog times fun when',
#  'one frog say to the other frog times fun when youre',
#  'frog say to the other frog times fun when youre having',
#  'say to the other frog times fun when youre having flies',
#  'to the other frog times fun when youre having flies why',
#  'the other frog times fun when youre having flies why did',
#  'other frog times fun when youre having flies why did the',
#  'frog times fun when youre having flies why did the boy',
#  'times fun when youre having flies why did the boy take',
#  'fun when youre having flies why did the boy take a',
#  'when youre having flies why did the boy take a pencil',
#  'youre having flies why did the boy take a pencil and',
#  'having flies why did the boy take a pencil and paper',
#  'flies why did the boy take a pencil and paper to',
#  'why did the boy take a pencil and paper to bed',
#  'did the boy take a pencil and paper to bed he',
#  'the boy take a pencil and paper to bed he was',
#  'boy take a pencil and paper to bed he was told',
#  'take a pencil and paper to bed he was told to',
#  'a pencil and paper to bed he was told to draw',
#  'pencil and paper to bed he was told to draw the',
#  'and paper to bed he was told to draw the curtains',
#  'paper to bed he was told to draw the curtains before',
#  'to bed he was told to draw the curtains before going',
#  'bed he was told to draw the curtains before going to',
#  'he was told to draw the curtains before going to sleep',
#  'was told to draw the curtains before going to sleep clean',
#  'told to draw the curtains before going to sleep clean joke',
#  'to draw the curtains before going to sleep clean joke about',
#  'draw the curtains before going to sleep clean joke about sorority',
#  'the curtains before going to sleep clean joke about sorority girls',
#  'curtains before going to sleep clean joke about sorority girls why',
#  'before going to sleep clean joke about sorority girls why do',
#  'going to sleep clean joke about sorority girls why do sorority',
#  'to sleep clean joke about sorority girls why do sorority girls',
#  'sleep clean joke about sorority girls why do sorority girls only',
#  'clean joke about sorority girls why do sorority girls only travel',
#  'joke about sorority girls why do sorority girls only travel in',
#  'about sorority girls why do sorority girls only travel in odd',
#  'sorority girls why do sorority girls only travel in odd numbered',
#  'girls why do sorority girls only travel in odd numbered groups',
#  'why do sorority girls only travel in odd numbered groups because',
#  'do sorority girls only travel in odd numbered groups because they',
#  'sorority girls only travel in odd numbered groups because they cant',
#  'girls only travel in odd numbered groups because they cant even',
#  'only travel in odd numbered groups because they cant even what',
#  'travel in odd numbered groups because they cant even what did',
#  'in odd numbered groups because they cant even what did the',
#  'odd numbered groups because they cant even what did the 8',
#  'numbered groups because they cant even what did the 8 say',
#  'groups because they cant even what did the 8 say to',
#  'because they cant even what did the 8 say to the',
#  'they cant even what did the 8 say to the 0',
#  'cant even what did the 8 say to the 0 hey',
#  'even what did the 8 say to the 0 hey fatty',
#  'what did the 8 say to the 0 hey fatty knock',
#  'did the 8 say to the 0 hey fatty knock knock',
#  'the 8 say to the 0 hey fatty knock knock whos',
#  '8 say to the 0 hey fatty knock knock whos there',
#  'say to the 0 hey fatty knock knock whos there sombrero',
#  'to the 0 hey fatty knock knock whos there sombrero sombrero',
#  'the 0 hey fatty knock knock whos there sombrero sombrero who',
#  '0 hey fatty knock knock whos there sombrero sombrero who sombrero',
#  'hey fatty knock knock whos there sombrero sombrero who sombrero ver',
#  'fatty knock knock whos there sombrero sombrero who sombrero ver the',
#  'knock knock whos there sombrero sombrero who sombrero ver the rainbow',
#  'knock whos there sombrero sombrero who sombrero ver the rainbow im',
#  'whos there sombrero sombrero who sombrero ver the rainbow im reading',
#  'there sombrero sombrero who sombrero ver the rainbow im reading a',
#  'sombrero sombrero who sombrero ver the rainbow im reading a book',
#  'sombrero who sombrero ver the rainbow im reading a book about',
#  'who sombrero ver the rainbow im reading a book about anti',
#  'sombrero ver the rainbow im reading a book about anti gravity',
#  'ver the rainbow im reading a book about anti gravity its',
#  'the rainbow im reading a book about anti gravity its impossible']

# %%
# inputs and targets
x, y = [], []

for i in seqs:
    seqx = " ".join(i.split()[:-1])
    x.append(seqx)
    seqy = " ".join(i.split()[1:])
    y.append(seqy)

# %%
num2word = {}
i = 0

for w in set(data.split()):
    num2word[i] = w
    i+= 1
    
word2num = {t: i for i, t in num2word.items()}

vocab_size = len(num2word)
vocab_size
# Out:
# 4717

# %%
def tokenizer(seq):
    return [word2num[w] for w in seq.split()]

# Tokenize
x_int = np.array([tokenizer(i) for i in x])
y_int = np.array([tokenizer(i) for i in y])

# %%
def get_batches(x, y, size):
    count = 0
    for i in range(size, x.shape[0], size):
        x1 = x[count:i,:]
        y1 = y[count:i,:]
        count = i
        yield x1, y1

# %%
class WordLSTM(nn.Module):
    
    def __init__(self, n_hidden=256, n_layers=4, drop=0.1, lr=0.001):
        super().__init__()

        self.drop = drop
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        self.emb_layer = nn.Embedding(vocab_size, 200)

        self.lstm = nn.LSTM(200, n_hidden, n_layers, 
                            dropout=drop, batch_first=True)
        
        self.dropout = nn.Dropout(drop)
        self.fc = nn.Linear(n_hidden, vocab_size)      
    
    def forward(self, x, hidden):

        embedded = self.emb_layer(x)     
        lstm_output, hidden = self.lstm(embedded, hidden) 
        output = self.dropout(lstm_output).reshape(-1, self.n_hidden) 
        output = self.fc(output)
        
        return output, hidden
    
    
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        if (torch.cuda.is_available()):
              hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(), weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        else:
              hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(), weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        return hidden

# %%
model = WordLSTM()
model.to('cuda')
print(model)
# Out:
# WordLSTM(
#   (emb_layer): Embedding(4717, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.1)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc): Linear(in_features=256, out_features=4717, bias=True)
# )

# %%
def train(model, epochs=100, batch_size=128, lr=0.001):
    
    opt = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    # push model to GPU
    model.cuda()
    model.train()

    for i in range(epochs):

        h = model.init_hidden(batch_size)
        
        for x, y in get_batches(x_int, y_int, batch_size):
            
            x = torch.from_numpy(x)
            x = torch.tensor(x).to(torch.long)
            y = torch.from_numpy(y)
            y = torch.tensor(y).to(torch.long)
            
            inputs, targets = x, y
            inputs, targets = inputs.cuda(), targets.cuda()

            h = tuple([each.data for each in h])


            model.zero_grad()

            output, h = model(inputs, h)

            loss = criterion(output, targets.view(-1))

            loss.backward()

            nn.utils.clip_grad_norm_(model.parameters(), 1)

            opt.step()            
       
        print("Epoch ", i+1, "loss ", loss.item())

# %%
def predict(model, tkn, h=None):

    # If the word isn't seen yet there will be no key for the dictionary, it defaults to 'the'
    key = word2num.get(tkn, word2num['the'])
    x = np.array([[key]])
    
    inputs = torch.from_numpy(x)
    inputs = inputs.cuda()

    h = tuple([each.data for each in h])
    out, h = model(inputs, h)

    # token probabilities
    prob = F.softmax(out, dim=1).data.cpu()
    prob = prob.numpy()
    prob = prob[0].reshape(prob.shape[1],)
    top_n_idx = prob.argsort()[-3:][::-1]
    sampled_word_index = top_n_idx[0]

    print(sorted(prob, reverse = True)[0:3])
    print(num2word[top_n_idx[0]], num2word[top_n_idx[1]], num2word[top_n_idx[2]])

    return num2word[sampled_word_index], h


# generate text
def generate(model, length, text):      
    model.cuda()
    model.eval()

    h = model.init_hidden(1)
    text = text.lower()
    sentence = text.split()

    for t in text.split():
        word, h = predict(model, t, h)
    
    sentence.append(word)

    for i in range(length-1):
        word, h = predict(model, sentence[-1], h)
        sentence.append(word)

    return ' '.join(sentence)

# %%
start = timer()
train(model, batch_size = 128, epochs=50)
end = timer()
print(end - start)
# Out:
# C:\Users\Mx\anaconda3\envs\b\lib\site-packages\ipykernel_launcher.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# C:\Users\Mx\anaconda3\envs\b\lib\site-packages\ipykernel_launcher.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Epoch  1 loss  6.861321926116943
# Epoch  2 loss  6.628620147705078
# Epoch  3 loss  6.3079094886779785
# Epoch  4 loss  6.046767234802246
# Epoch  5 loss  5.793934345245361
# Epoch  6 loss  5.575216770172119
# Epoch  7 loss  5.385983467102051
# Epoch  8 loss  5.277525901794434
# Epoch  9 loss  5.123063087463379
# Epoch  10 loss  4.98129415512085
# Epoch  11 loss  4.848435878753662
# Epoch  12 loss  4.675694465637207
# Epoch  13 loss  4.479979515075684
# Epoch  14 loss  4.315096378326416
# Epoch  15 loss  4.411412239074707
# Epoch  16 loss  4.260664939880371
# Epoch  17 loss  4.040541648864746
# Epoch  18 loss  3.9297027587890625
# Epoch  19 loss  3.874598264694214
# Epoch  20 loss  3.7350406646728516
# Epoch  21 loss  3.5999152660369873
# Epoch  22 loss  3.4346835613250732
# Epoch  23 loss  3.3783538341522217
# Epoch  24 loss  3.2846622467041016
# Epoch  25 loss  3.1634631156921387
# Epoch  26 loss  3.122891902923584
# Epoch  27 loss  2.9297072887420654
# Epoch  28 loss  2.8474392890930176
# Epoch  29 loss  2.756193161010742
# Epoch  30 loss  2.6704089641571045
# Epoch  31 loss  2.562769889831543
# Epoch  32 loss  2.6145453453063965
# Epoch  33 loss  2.4973511695861816
# Epoch  34 loss  2.4781641960144043
# Epoch  35 loss  2.377619981765747
# Epoch  36 loss  2.287370443344116
# Epoch  37 loss  2.202481746673584
# Epoch  38 loss  2.220491647720337
# Epoch  39 loss  2.0654399394989014
# Epoch  40 loss  1.94476318359375
# Epoch  41 loss  1.8705861568450928
# Epoch  42 loss  1.9094674587249756
# Epoch  43 loss  1.7344413995742798
# Epoch  44 loss  1.7070516347885132
# Epoch  45 loss  1.674330472946167
# Epoch  46 loss  1.6229559183120728
# Epoch  47 loss  1.5413188934326172
# Epoch  48 loss  1.5077695846557617
# Epoch  49 loss  1.3966032266616821
# Epoch  50 loss  1.4252705574035645
# 186.56102909999998

# %%
np.set_printoptions(precision=3, suppress=True)

# %%
print(generate(model, 3, "knock knock whos"))
print("")
generate(model, 1, "there")
# Out:
# [0.17078434, 0.07750105, 0.07073179]
# who why knock
# [0.58684105, 0.07083722, 0.04232638]
# knock whos com
# [0.9480909, 0.0057749725, 0.004183191]
# there hes youre
# [0.15096, 0.14922044, 0.12390228]
# boo sombrero impatient
# [0.7003772, 0.07340678, 0.038031053]
# boo sombrero ash
# knock knock whos there boo boo
#
# [0.1484022, 0.08830034, 0.0808735]
# are were dont
# 'there are'
